# %% [markdown]
# ## Tweeting like Trump - Generating Trump-like tweets using Stacked LSTMs
#
# #### By: Ian Herve U. Chu Te
#
# In this notebook, we use a **two-layer LSTM model** to learn from U.S. President Donald Trump's tweets and generate new unique tweets from them (complete with hashtags, tags and links).
#
# The data we use is sourced from Kaggle's **Better Donald Trump Tweets** dataset. You may download the dataset <a href="https://www.kaggle.com/kingburrito666/better-donald-trump-tweets">here</a>.

# %% [markdown]
# ### 1. Feature Engineering
#
# Raw text data cannot be directly fed into the LSTM model. We have to engineer the data first before we can proceed to the modelling step.

# %% [markdown]
# Firstly, let us import some libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Then, let us load the dataset.
#
# **NOTE: **If you wish to reuse this notebook, download the <a href="https://www.kaggle.com/kingburrito666/better-donald-trump-tweets">Kaggle Dataset</a> and unzip and rename the csv file to *data.csv*.

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#        Date      Time                                         Tweet_Text  \
# 0  16-11-11  15:26:37  Today we express our deepest gratitude to all ...
# 1  16-11-11  13:33:35  Busy day planned in New York. Will soon be mak...
# 2  16-11-11  11:14:20  Love the fact that the small groups of protest...
# 3  16-11-11   2:19:44  Just had a very open and successful presidenti...
# 4  16-11-11   2:10:46  A fantastic day in D.C. Met with President Oba...
#
#    Type Media_Type   Hashtags      Tweet_Id  \
# 0  text      photo  ThankAVet  7.970000e+17
# 1  text        NaN        NaN  7.970000e+17
# 2  text        NaN        NaN  7.970000e+17
# 3  text        NaN        NaN  7.970000e+17
# 4  text        NaN        NaN  7.970000e+17
#
#                                            Tweet_Url  \
# 0  https://twitter.com/realDonaldTrump/status/797...
# 1  https://twitter.com/realDonaldTrump/status/797...
# 2  https://twitter.com/realDonaldTrump/status/797...
# 3  https://twitter.com/realDonaldTrump/status/796...
# 4  https://twitter.com/realDonaldTrump/status/796...
#
#    twt_favourites_IS_THIS_LIKE_QUESTION_MARK  Retweets  Unnamed: 10  \
# 0                                     127213     41112          NaN
# 1                                     141527     28654          NaN
# 2                                     183729     50039          NaN
# 3                                     214001     67010          NaN
# 4                                     178499     36688          NaN
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# All we need is the **Tweet_Text** field. Let us combine all the rows to create a text corpus by concatenating tweets but separating them with two newlines:

# %%
text = '\n\n'.join(data['Tweet_Text'].values)

# %% [markdown]
# To reduce the size of our feature space and our training time, we remove rare characters:

# %%
from collections import Counter
import re

# %%
cntr = Counter(text)
rare = list(np.asarray(list(cntr.keys()))[np.asarray(list(cntr.values())) < 300])
for c in rare:
    text = re.sub('[' + c + ']', '', text)

# %% [markdown]
# Here is how the start of the corpus looks like:

# %%
text[:1000]
# Out:
# 'Today we express our deepest gratitude to all those who have served in our armed forces. #ThankAVet https://t.co/wPk7QWpK8Z\n\nBusy day planned in New York. Will soon be making some very important decisions on the people who will be running our government!\n\nLove the fact that the small groups of protesters last night have passion for our great country. We will all come together and be proud!\n\nJust had a very open and successful presidential election. Now professional protesters, incited by the media, are protesting. Very unfair!\n\nA fantastic day in D.C. Met with President Obama for first time. Really good meeting, great chemistry. Melania liked Mrs. O a lot!\n\nHappy 241st birthday to the U.S. Marine Corps! Thank you for your service!! https://t.co/Lz2dhrXzo4\n\nSuch a beautiful and important evening! The forgotten man and woman will never be forgotten again. We will all come together as never before\n\nWatching the returns at 9:45pm.\n#ElectionNight #MAGA__ https://t.co/HfuJeRZbod\n\nRT @IvankaT'

# %% [markdown]
# The corpus is 857177 characters long and there are 78 unique characters within it:

# %%
print('corpus length:', len(text))
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 857177
# total chars: 78

# %% [markdown]
# Now, let us cut the text in semi-redundant sequences of *maxlen* characters so that it can be fed into an LSTM model:

# %%
maxlen = 50
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 285709

# %% [markdown]
# Then, let us vectorize the sentences:

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ### 2. Generative Modelling
#
# Now we can proceed to the modelling phase.

# %% [markdown]
# First, let us import *Keras* - a powerful neural network library.

# %%
from __future__ import print_function
import random
import sys
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Let's create some reusable functions that can sample and generate text from our generative model:

# %%
cntr = Counter(text)
cntr_sum = sum(cntr.values())
char_probs = list(map(lambda c: cntr[c] / cntr_sum, chars))

# %%
def sample(preds):
    preds = np.asarray(preds).astype('float64')
    preds = preds / np.sum(preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate(model, length, seed=''):
    
    if len(seed) != 0:
        sys.stdout.write(seed)
    
    generated = seed
    sentence = seed
    
    for i in range(length):
        x = np.zeros((1, maxlen, len(chars)))

        padding = maxlen - len(sentence)
        
        for i in range(padding):
            x[0, i] = char_probs # pad using the priors
            
        for t, char in enumerate(sentence):
            x[0, padding + t, char_indices[char]] = 1.

        preds = model.predict(x, verbose=0)[0]
        next_index = sample(preds)
        next_char = indices_char[next_index]

        sentence = sentence[1:] + next_char
        generated += next_char
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
        
    return generated

# %% [markdown]
# Now, let us a build the graph of our neural network.
#
# Afterwards, let us train our model, and display some samples at every epoch.
#
# At the end of the training, we save the model so we can quickly reuse it in the future.

# %%
from os.path import isfile
from keras.models import load_model

MODEL_PATH = 'stacked-lstm-2-layers-128-hidden.h5'

if isfile(MODEL_PATH):
    model = load_model(MODEL_PATH)
else:
    N_HIDDEN = 128

    model = Sequential()
    model.add(LSTM( \
        N_HIDDEN, dropout=0.1, input_shape=(maxlen, len(chars)), return_sequences=True))
    model.add(LSTM(N_HIDDEN, dropout=0.1))
    model.add(Dense(len(chars), activation='softmax'))

    optimizer = RMSprop(lr=0.01)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)

    for iteration in range(1, 40):
        print('\n')
        print('-' * 50)
        print('\nIteration', iteration)
        model.fit(X, y, batch_size=3000, epochs=1)

        print('\n-------------------- SAMPLE ---------------------\n')

        rand = np.random.randint(len(text) - maxlen)
        seed = text[rand:rand + maxlen]
        generate(model, 400, seed)

    model.save(MODEL_PATH)
# Out:
# --------------------------------------------------
#
# Iteration 1
# Epoch 1/1
# 285709/285709 [==============================] - 50s - loss: 3.1476
#
# -------------------- SAMPLE ---------------------
#
#  put up approximately 50 million for my successfull es FoK Tump mumird bis Vof loutp oremy Fall #/axhoor,. Tho iss Tf amy lutrns ailr Corrt
# #Ahate,s dort is bhitin fafd yhis hacs Wial yor yrup thin Caryant te mety aund Bonnt wacy targypos na as 1 ufpin  ibe bo sestant yornor:e.. Eus aseind frort. https://t.co/pfIGPBKKh
#
# "@coners Horlerd I mtaris het haalda bopp dorele omrst. AAgoo MaGDingare abtins Here - ant brinn @atpad bo the  eakop me batp of
#
# --------------------------------------------------
#
# Iteration 2
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 2.2836
#
# -------------------- SAMPLE ---------------------
#
# aldJTrumpJr: An Honor to be in #Indiana w @realDonaldTTump is upsor homqrtup soas. The bern. Sated pestibey!
#
# De that bezt
# with the nutterteljo. #TrumpT nathxesdering pesterg lest and THPSCs! https://t.co/xGr8e_tOqV https://t.co/KPWaJI7lHD"
#
# Tnggreight oppaile allmenss far Beart Geating sameaty
#
# Thank!"
#
# "@belevis3ft@nowaldhtry.
#
# To chump deolt.../hnar becclith!
#
# "@Jusbyad on ighowour maljertpe, ophe ned!
#
# DHonverdifpire to myall....creyink G We
#
# --------------------------------------------------
#
# Iteration 3
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.9914
#
# -------------------- SAMPLE ---------------------
#
# ue about Univision and Fusion? Wow!?!  http://t.co/EuO6jQ7h?
#
# Nf  all ond the about" Deff ention by in ASfiffflonive car Fairioo, lut thy my that for tatchy newing ton for Coumalins mowo. Lifgs thy from thang the he been that sart the werl mott fir of the netervewed lited sainet boaffrest forfabet of ot the mack. Why Trump. Am_
#
# "@mandyonst @BiakSbeCt "@readDonaldTrump @Uarnita  1: He weiter we en P0 tark you!
#
# The cin!
#
# "@mkthe 24d trut the debs
#
# --------------------------------------------------
#
# Iteration 4
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.8399
#
# -------------------- SAMPLE ---------------------
#
# of Cataclysmic۪ Losses With Ted Cruz, and Says Donald Trump spesitus of @GMOEJPLLD Op, I on your, an igtroting to agonalage at 13:00P.!!!
# #Im
# #FoxNeds juts will @MoCingonTers4. We said whire my the know pronoters wolk againgthis pustirs wingt farsingty I pupps my for the undecfilling has win promett. Gody @josbfeney as forgatice. #getats will pushinged of @phgetimbor has but surby &amp; Whoner. Best will besingest wowe for it, country interestict
#
# --------------------------------------------------
#
# Iteration 5
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.7468
#
# -------------------- SAMPLE ---------------------
#
# so much for the wonderful statements you made about in Ilvapion has why deell whot so are should liker them
#
# I lalities country not abrosted beal deally office. Theypens gooverfulliral who tooal-molst herdong beal thoteple good chard is against loide clowers, mull was America Last in the whe dood, then how. Rookeds Really" https://t.co/3BtYkNPWiIACF
#
# 6 person in I.B. Trump is and forward cowntrof?"
#
# "@MhrWus@Kph00: @realDonaldTrump Lots to I cell
#
# --------------------------------------------------
#
# Iteration 6
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.6833
#
# -------------------- SAMPLE ---------------------
#
# n @foxandfriends at 7:30 A.M.
#
# "@MyPresidentme: He made so fooMher loves Aboth you. http://t.co/LwGHQyqG
#
# Hester. Evized be bunnight at 9.0,00 1/himmigrally!"
#
# "@tod00tirtanry great EmAm: http_
#
# .@OROCDebate ussold it of yetriigeming. I Im nothan thought!
#
# Just soplated amoman, oner big!!
#
# "@Ashargn: Madstose on Tamesic to cradd yho apporting that repind. The becomem evening mornidation think Donald Trump"
#
# Vight #DrainTheSwamprand to can @youdMo
#
# --------------------------------------------------
#
# Iteration 7
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.6347
#
# -------------------- SAMPLE ---------------------
#
# the late great John Wayne. Our country could use and the new has have country. A lowfine we mads goning twive."! Gtgge thingrent nice going today. #Trump2016 #Trump2016
# https://t.co/yN9oQ3Fcv79
#
# RT @NACYRORIwER: @ALMAKERICS IO will be it wome is recood promz is!
#
# Join me in 11/8/01k are are wonders- vote w/ BoTr guy.
#
# "@lint_librere: @realDonaldTrump coass an greak viesional lemport, me!
#
# New it is hiadiral law the president! #MAGA https://t.co/
#
# --------------------------------------------------
#
# Iteration 8
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.5995
#
# -------------------- SAMPLE ---------------------
#
# nald!!! And The People You Are Running Against Willary. Talent press Trump Makeline, News
#
# .@NewProvinah Isal need to their new his rewond that theur shisement are in keepicans to she well is going to supporters in NevandoH Im New Hampshire! Thank you The Hispanican  that @realDonaldTrump would now the Republican Choibite, In Seray. https://t.co/qZ1cle8uYIi" It was say great me in @realDonaldTrump his Sunday Donald Trump com۪ng to 37mp Primary an
#
# --------------------------------------------------
#
# Iteration 9
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.5684
#
# -------------------- SAMPLE ---------------------
#
# t on the http://t.co/SIppNYk834
#
# "@WalterEKurtzJr: @GSneSomnooly @Morning_Joe @realDonaldTrump OraigcartNewn
#
# Thank you @Trumpscets Fox ulopad faurences president, more for President/-Ow? No VStter, Ogon, Plone on the poll for hin the slent!
# #Trump3016 https://t.co/pN3eL7Bacjb"
#
# Masts niverity Most my all dont well even to soll. I do the @megynkels the trying run-just win one rune 19, Million an the perile, the @BornelySC #MAKEAritaFleatAgain htt
#
# --------------------------------------------------
#
# Iteration 10
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.5446
#
# -------------------- SAMPLE ---------------------
#
# t7fh
#
# Looking forward to joining @V4SA Tuesday 9/11- the people! #MorryVite #Trump2016"
#
# "@dseilavialo1: @Regynkilly Hedory - VERESING IT down Carty has
#
# Join me in Carson Fox morning to tame and savest his Cerson."
#
# "@MardHaruzDon: @realDonaldTrump @cMSG. @hanketherloy @anal DonaldTrump https://t.co/tCvxIAfLw
#
# .@ptertyrs8els, that hes dight!
#
# With @realDonaldTrump for think him is just smring the sares @realDonaldTrump 13 earry nican5
#
# "@DlengPa
#
# --------------------------------------------------
#
# Iteration 11
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.5220
#
# -------------------- SAMPLE ---------------------
#
# t national security threat. It must be stopped in resulting that "times to be big
#
# "@Coth: DV COA: @Ppity4211-@DanSauida @charstors surin thing poll, interest.
# Legan Sanders! American ratings loves! I happening. Votes nest than a opherifled somelionship contro with I think Colical prifantas stand to be over seeing savesed the good by to be the perbluck. New a grouple togot? But so noborser country Sat, Causss by it. The Wall to do people and very
#
# --------------------------------------------------
#
# Iteration 12
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.5033
#
# -------------------- SAMPLE ---------------------
#
# oin me on Wednesday, May 25th at the Anaheim Convention- Bola Grovis tomorrow &amp; speech in U.S. insideed running in MEG, #Utacurgal. Mokes in trulted President spectal only unquole.
#
# I will be manning my laying togal U.S. voter for 4 BEPKECA, and julgt, just our Negas, President"
#
# "@Fox4JIN: Mennia - has just۪s a compan, just criding to rupping terrorisis - job and our meing. WILLERGRWTRO  IMER - #Trump2016
# Plemuole, seening all piect for "tru
#
# --------------------------------------------------
#
# Iteration 13
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4881
#
# -------------------- SAMPLE ---------------------
#
# s Trump in the lead by double digits" https://t.co/SBInDRPL0Oq"
#
# Congrateculan @KokeHero_Millary oldnt for Mitts Builn Dents professe!
#
# "@je1: @tOEDATET was just an apilund! Crooked Hillary Clinton. Would a crowd, banks?"
#
# "@jongirgtth01: @CNNpoloturs @GSte @DanScavino @realDonaldTrump you muthen covtirvent @jestylongbirs. No scene! Great going with voters needs. I am antielly I am sy a candidate ---!
#
# .@realDonaldTrump is want a litr beau in Sta
#
# --------------------------------------------------
#
# Iteration 14
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4743
#
# -------------------- SAMPLE ---------------------
#
# ke_pence tonight- join us: https://t.co/hre7FofPxQh
#
# "@bomtorwhrQ41: @CNN @RoneradCGolino @realDonaldTrump In yout stropgel! https://t.co/GN4fZUY1iF
#
# "@jmiome33 @realDonaldTrump I can sayenceed to Presidential BUVE looking put me for the could wrong about the no, michal interoulitiou people to be the nother the voting to voter with win, Crooked Hillarys should IN to servust take our campaign cover mease #1 time, with @Morning_Joe https://t.co/kE
#
#
# --------------------------------------------------
#
# Iteration 15
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4629
#
# -------------------- SAMPLE ---------------------
#
# ere I lead by big numbers, shows that in a head to me that has big right frue!
#
# We jours any New York, Virg Poll Trump jobs and when the finsing. You debate. A great juign۪t back of just a great Scough Polling Sarbara!
# #MakeAMericaGreatAgain
#
# "@Rindoingera: @ricDasTamkWaners"
#
# "@Willot: Wall be lun, &amp; junghing my freez to lins. Bush show of the t.C. Dry specials like the Repiblican Party -  Very wrong! Sarnd hell dup new goverped the moments
#
# --------------------------------------------------
#
# Iteration 16
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4516
#
# -------------------- SAMPLE ---------------------
#
# .co/32gdX684ew
#
# I will be interviewed on @greta tonight Fox Jeb Bush, unhally a ralling of politics are honor thats wont be the pressuct plan USSE"
#
# "@doetmantz: @realDonaldTrump You anoth even he going horribent in Iowa! Nave a supports Control As Donald Trump is day." Looks show and about Stame Rubio - deal in 10 may and elect in the polss who vrious in Pain Amering - and better leads with man, an for Americans, the realif on Hope S.canders Hil
#
# --------------------------------------------------
#
# Iteration 17
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4396
#
# -------------------- SAMPLE ---------------------
#
# /svQQhAHBow
#
# New CNN Iowa poll --- Trump 33, Cruz explaged of the most people anothing for have levil wan in Bengha, &amp; lending the great self funding all politics in his figure!
#
# Is no wif to #MakeAmericaGreatAgain"
#
# "@DicurannSC @realDonaldTrump Going to swect of this supporter! https://t.co/T7MaV8BZS0
#
# #IowaLeb Poth! #Trump2016 https://t.co/vUwdAFIYB5t
#
# .@H. really Crooked۪ wrotborded to so troon just office mading strond to wish entoused t
#
# --------------------------------------------------
#
# Iteration 18
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.4313
#
# -------------------- SAMPLE ---------------------
#
# "
#
# "@RonnieMemo: DonaldTrump is a leader. He is a protect on them.
#
# Lous on AL, me resolrchard to WIN
#
# "@decaurelve: Good for @.w6,pamonia and the same. Why do this colled I im a let a childration." Citured worse on The Getay for friend.
#
# "@wellythater: @morningmics @realDonaldTrump Hillary Clintons to be correct on Washington. Time the state Trump &amp; veryong I am be doef. We are be all on CNN.
#
# "@StiePfarsz: "Ht out race on reportor to the he
#
# --------------------------------------------------
#
# Iteration 19
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3870
#
# -------------------- SAMPLE ---------------------
#
# n CNN!
#
# "@ElviNichols: Will @CNN be tough as they cannot gun ard liston." https://t.co/Bo6XfvGIw9 https://t.co/tpQLhsjyrCb
#
# The was and the disapture, your night. Its he win This, going to fix the-2 Dars - Clease One McCain!
#
# I will be interview on China that 600 in #Caucus Bush has debates ofter throws. See much farricit. Very lages tonight at that he WILL WIN"
#
# HOUS BATISICINANG STREAT https://t.co/8LkP3R8qvl"
#
# "@jmartayl:  @foxandfriends at 7:
#
# --------------------------------------------------
#
# Iteration 25
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3815
#
# -------------------- SAMPLE ---------------------
#
# watches the @GolfChannel
#
# Ohio Gov.Kasich voted for her &amp; stand @realDonaldTrump on the 1 wank, you find Hillary, Chris McMalton. game America Great Again forey never male this Lyin Meary Leaders-ind won the forcere to goo !!!"
#
# "@Carland2: @realDonaldTrump is Allantan- apport in Lercourn, going to tas nution and so put supporters losien @foxandfriends #Trump2016 https://t.co/0GyNkIs0IV
#
# Thank you for illinging into the globbying!
#
# Is very bi
#
# --------------------------------------------------
#
# Iteration 26
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3760
#
# -------------------- SAMPLE ---------------------
#
# s - all others are status quo #MakeAmericaGreatAgain!
#
# I will be on @FluneTrump is TPEILENTE #DakelAmerica great!
#
# "@Rentarnie: @realDonaldTrump 118 funny for cant finally clear but not Clain!
#
# Wow, I dont want۪ will do the @TODAYshamed who wants to show a state-the women. I would take it for wife!
#
# Hispagace, a smills, just last tegetion on 2 umress.
#
# Crooked Hillary Cliston join us Donald Trump 32 Cless Otioka. #Trump2016
#
# Problegs in TV,R. Enj
#
# --------------------------------------------------
#
# Iteration 27
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3735
#
# -------------------- SAMPLE ---------------------
#
# support! TOGETHER we will MAKE AMERICA GREAT AGAIN!"
#
# "@MikcLeyBustickand: @realDonaldTrump you mind of woll speak rann in Graham for years &amp; you she has defend it to get a stablishment prejicision in 200/15.3 Supio and get youre۪s good for shlaph!
#
# Lightwatc media cant be massive Florida great job days  on me!
#
# Hillary Clinton pifacked guy he is out lat this morning by @Willagar- - TRUMP 55.5!"
#
# "@KattyMabBorg49: @realDonaldTrump #Debates201
#
# --------------------------------------------------
#
# Iteration 28
# Epoch 1/1
# 285709/285709 [==============================] - 48s - loss: 1.3654
#
# -------------------- SAMPLE ---------------------
#
# lDonaldTrump !!!  #Trump2016"
#
# "@tonyparker1981: @realDonaldTrump 129: A told this toply for a best self fortuse------ great grand. She deal say than John, more life books for D.C. fer illegally thank you, Hundia Will be so go on the preble to watch."
#
# "@RublattAleC_Cin: I will refeal.
#
# GO Andryqpartion, the reasons 4t Our fasticting good. New Vet There!
#
# Thank you for your damber.
#
# DA won endorsement just prostidence, not doesnt thinks on #AM po
#
# --------------------------------------------------
#
# Iteration 29
# Epoch 1/1
# 285709/285709 [==============================] - 48s - loss: 1.3620
#
# -------------------- SAMPLE ---------------------
#
# sell Moore is truly a terrible representative of Everyone callage.
#
# Nobo, heart on new going given videc over GOP candidate"
#
# "@andami3nore: Trump: Miaginnel Hillary and @TheHic. Its last night!
#
# "@notleenings9: https://t.co/Nd6hLJJ14J
#
# Will be lain!
# #MakeAmericaGreatAgain"
#
# I will be bring the #VetenHire to @NowingSianion said, he has deentime!
#
# If Trump, Barelodielen. Lied that I told it
#
# "@seevarsan: @realDonaldTrump is not a great support.
#
# "
#
# --------------------------------------------------
#
# Iteration 30
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3392
#
# -------------------- SAMPLE ---------------------
#
# ho knows who they are - some could be ISIS. Is our presidentials!
# https://t.co/yNLJsIEPDPq
#
# People! The USH watching, whipe of Atirgy?
#
# Do Ted Cruz Policy own of the perill edicons--poll who got a homeogn at 12p
#
# Uniteds  Thank you for the way to you! Nice!
#
# Hope proud of a madaia, who giving a real story in The Family!
#
# .@TheFilliovsibs kean in up and fow attention appoivilied." Get out, HAP
#
# The plafes is tike the pampions unkatinots changing t
#
# --------------------------------------------------
#
# Iteration 36
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3340
#
# -------------------- SAMPLE ---------------------
#
# ow with Mark!
#
# "@Knight276: @Writeonright @Real_Caike @seputtors- You ROCKET @FoxNews is not puppet greaters he can mer and pue! Thankfully, beginnative!
#
# See you said that way are sealing amazing-very one of the major"
#
# "@11d_۪uch: @realDonaldTrump My was the spenten Poll with Cripples lets I can they, to run in Senator Carson in Timesh North, Ronishin with Jeb Bushy۪s 4/1/25 https://t.co/mJLLkwpKNbe
#
# Why will have are feghoner of Careotic Lates
#
# --------------------------------------------------
#
# Iteration 37
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3315
#
# -------------------- SAMPLE ---------------------
#
# R TRUTH"
#
# "@_trump4potus: Trump continues to rise to be opponestion and politics on job on @FoxNews time! We must come are fixalions!
#
# Det۪z Virginia https://t.co/rDGyfZBfXp
#
# Because New 2 Give, Texon!
#
# "@talre_00: @realDonaldTrump @realDonaldTrump @gettompertor shown Missimst State s.Pock @Morning_Joe  Mr. Trumps join!
#  #TeamTrump
#
# "@Dazidey69: @realDonaldTrump Attte nick - HOU!
#
# Great job @Danid_GruehSA. Thank you! #NAPrimarics https://t.co/4wB
#
# --------------------------------------------------
#
# Iteration 38
# Epoch 1/1
# 285709/285709 [==============================] - 48s - loss: 1.3285
#
# -------------------- SAMPLE ---------------------
#
# ation:
# https://t.co/2twuzrB9om
#
# Will be interviewed on @jisguvinionPolitics numbers tonight. @megynkelly by money to diskumence, is it."
#
# "@nRosingilo96: @sspeckershappeten: @realDonaldTrump @realDonaldTrump V.A.A and every 3barawon tonight It have the most turnouts blate to seryt: https://t.co/3P8tW7GEiO HS CBAZ!"
#
# "@Dangw23016: @realDonaldTrump #DebateTrump" https://t.co/QlcZahKaPD
#
# RT @DreathGHerstain: What she POLL beat me! Worked all to Make
#
# --------------------------------------------------
#
# Iteration 39
# Epoch 1/1
# 285709/285709 [==============================] - 47s - loss: 1.3247
#
# -------------------- SAMPLE ---------------------
#
# jority felt she should be prosecuted..." -- even started delegiting throws way for you calling,brath intervation that thisking #MakeAmericaGreatAgain #Trump2016 https://t.co/8MpQxJm2v
# but I will be uslanting for.@Folks &amp; Dhew said Alwerry Stops Karis history is Morning, America &amp; @seanhannity yo say helling down.
#
# Belies Obama with a jokes wither ever funding my campaign.
#
# Our with the figure Ihry they know how to corrupt @realDonaldTrump

# %% [markdown]
# Now let's try out the model!
#
# Using the first sentence of this <a href='https://twitter.com/realDonaldTrump/status/890764622852173826'>tweet</a> as seed, let us try to continue Trump's sentence and see what interesting stuff our model can say:

# %%
sample_tweet_start = 'Go Republican Senators, Go!'
_ = generate(model, 200, sample_tweet_start)
# Out:
# Go Republican Senators, Go!.. Big crowd! I will be last thoughts.
#
# The everyone be not look encertive - https://t.co/6dcnr62pna
#
# They get I will people is you.!
#
# "@KathyFurnAnier: @getepkis26 16 @BirlinieleyBy34Ie ht_
#
# Just doe
